# %%
import pandas as pd

# %%
df = pd.read_csv('../data/diversion_rates.csv')

# %%
df
# Out:
#         Month  BKN01 Diversion Rate  BKN02 Diversion Rate  \
# 0        July                  16.4                  18.9
# 1      August                  16.2                  20.1
# 2   September                  15.3                  19.9
# 3     October                  15.0                  19.8
# 4    November                  15.1                  20.2
# 5    December                  16.3                  21.9
# 6     January                  17.1                  22.5
# 7    February                  15.9                  20.6
# 8       March                  15.7                  19.7
# 9      April                   14.7                  20.0
# 10        May                  15.7                  19.5
# 11       June                  16.1                  20.5
#
#     BKN03 Diversion Rate  BKN04 Diversion Rate  BKN05 Diversion Rate  \
# 0                   11.7                  14.5                   9.8
# ...

# %%
data = {'Month': ['July', 'August', 'September', 'October', 'November', 'December', 'January', 'February', 'March',
                 'April', 'May', 'June'],
        'BKN01 Diversion Rate': [16.4,16.2,15.3,15.0,15.1,16.3,17.1,15.9,15.7,14.7,15.7,16.1],
        'BKN02 Diversion Rate': [18.9,20.1,19.9,19.8,20.2,21.9,22.5,20.6,19.7,20,19.5,20.5],
        'BKN03 Diversion Rate': [11.7,12,12.1,11.6,11.6,12.6,13.9,13,12.3,12.2,11.7,12.6],
        'BKN04 Diversion Rate': [14.5,14.7,14.5,14.2,14.3,15.5,17.1,15.8,16,15.5,15,16.4],
        'BKN05 Diversion Rate': [9.8,9.6,9.9,9.6,9.9,10.7,11.7,10.6,10.4,10.1,9.8,11],
        'BKN08 Diversion Rate': [15.5,15.5,15.9,16.1,16.6,17.2,19.8,17,16.9,16.4,15.7,17.2],
        'BKN09 Diversion Rate': [12.1,12.4,12.5,12,12.4,13.7,14.9,14,14.5,14,14.1,13.8],
       }

df = pd.DataFrame(data,columns=['Month','BKN01 Diversion Rate','BKN02 Diversion Rate','BKN03 Diversion Rate',
                               'BKN04 Diversion Rate','BKN05 Diversion Rate','BKN08 Diversion Rate','BKN09 Diversion Rate',])

av_column = df.mean(axis=0)
print (av_column)
# Out:
# BKN01 Diversion Rate    15.791667
# BKN02 Diversion Rate    20.300000
# BKN03 Diversion Rate    12.275000
# BKN04 Diversion Rate    15.291667
# BKN05 Diversion Rate    10.258333
# BKN08 Diversion Rate    16.650000
# BKN09 Diversion Rate    13.366667
# dtype: float64
